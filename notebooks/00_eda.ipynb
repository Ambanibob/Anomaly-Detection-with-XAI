# %% [markdown]
# # 00 - EDA & Sanity Checks
# Use this to explore `data/raw/` CSVs and sketch features.

# %%
import pandas as pd
from pathlib import Path
raw = Path('data/raw')
list(raw.glob('*.csv'))
